# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('2018-2022.csv')

# %%
df['timestamp'] = pd.to_datetime(df['INCIDENT_DATE'], format='%m/%d/%Y %I:%M:%S %p')
df['hour'] = df['timestamp'].dt.hour
df['month'] = df['timestamp'].dt.month
df['weekday'] = df['timestamp'].dt.dayofweek
# Out:
#        Unnamed: 0  LURN_SAK           INCIDENT_DATE  \
# 0              16  18615198  06/19/2018 03:00:00 AM
# 1             101  18542039  04/08/2018 09:35:00 PM
# 2             185  18700869  09/18/2018 10:00:00 AM
# 3             186  18695878  09/12/2018 06:30:00 AM
# 4             187  18700046  09/17/2018 11:00:00 AM
# ...           ...       ...                     ...
# 15784       62419  19831920  02/10/2022 10:15:00 AM
# 15785       62422  19818950  01/25/2022 07:15:00 AM
# 15786       62430  19862181  03/15/2022 12:00:00 PM
# 15787       62437  19881074  04/08/2022 10:07:30 PM
# 15788       62505  19867091  03/23/2022 08:14:00 PM
#
#                          CATEGORY  STAT  \
# 0                GRAND THEFT AUTO    91
# 1              AGGRAVATED ASSAULT    54
# 2                       VANDALISM   263
# 3                   LARCENY THEFT   386
# 4                   LARCENY THEFT   389
# ...                           ...   ...
# 15784  MISDEMEANORS MISCELLANEOUS   391
# 15785                     ROBBERY    38
# 15786     OFFENSES AGAINST FAMILY   174
# 15787               LARCENY THEFT   340
# 15788                    BURGLARY    61
#
#                                                  ADDRESS  LONGITUDE  LATITUDE  \
# 0                    1300 HARPER AVE, WEST HOLLYWOOD, CA   -118.368    34.095
# 1          600 ROBERTSON BLVD, WEST HOLLYWOOD, CA  90069   -118.385    34.080
# 2      7300 SANTA MONICA BLVD, WEST HOLLYWOOD, CA  90069   -118.351    34.092
# 3              1000 CROFT AVE, WEST HOLLYWOOD, CA  90046   -118.374    34.089
# 4       500 N LA CIENEGA BLVD, WEST HOLLYWOOD, CA  90048   -118.376    34.080
# ...                                                  ...        ...       ...
# 15784         8200 SUNSET BLVD, WEST HOLLYWOOD, CA 90069   -118.369    34.096
# 15785    1100 ORANGE GROVE AVE, WEST HOLLYWOOD, CA 90046   -118.360    34.091
# 15786        7700 FOUNTAIN AVE, WEST HOLLYWOOD, CA 90046   -118.358    34.094
# 15787         8700 SUNSET BLVD, WEST HOLLYWOOD, CA 90069   -118.382    34.091
# 15788        900 WEST KNOLL DR, WEST HOLLYWOOD, CA 90069   -118.377    34.087
#
#        PART_CATEGORY           timestamp  hour  month  weekday
# 0                  1 2018-06-19 03:00:00     3      6        1
# 1                  1 2018-04-08 21:35:00    21      4        6
# 2                  2 2018-09-18 10:00:00    10      9        1
# 3                  1 2018-09-12 06:30:00     6      9        2
# 4                  1 2018-09-17 11:00:00    11      9        0
# ...              ...                 ...   ...    ...      ...
# 15784              2 2022-02-10 10:15:00    10      2        3
# 15785              1 2022-01-25 07:15:00     7      1        1
# 15786              2 2022-03-15 12:00:00    12      3        1
# 15787              1 2022-04-08 22:07:30    22      4        4
# 15788              1 2022-03-23 20:14:00    20      3        2
#
# [15789 rows x 13 columns]

# %%
df.to_csv('2018-2022_timestamped.csv')
